# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

df=pd.read_csv("reviews_data.csv").dropna()

# %%
df.head()
# Out:
#   marketplace  customer_id       review_id  product_id  product_parent  \
# 0          US     32908537  R25Z46X8FXZQM0  B005LD2BAI       801608094
# 1          US     29266849  R11PEZB5ENERJ0  B000HK1OOY       650003661
# 2          US     12848580   RIX49JNVH1TGW  B004JK9CKG         5899548
# 3          US     49493237  R1SGJCCEN0GCPH  B002KQLUVU        89308012
# 4          US     48132869  R226MO6DFUWR4K   767921968       731560606
#
#                                        product_title  star_rating  \
# 0  Incredible Inc. Cleaner; Stain Remover; Deodor...            5
# 1  Dr. Bronner's Pure-Castile Liquid Soap - Baby ...            5
# 2  Top Performance ProDental Dental Spray — Easy-...            5
# 3                                            BB-8520            5
# 4  It's Called a Breakup Because It's Broken: The...            5
#
#    helpful_votes  total_votes vine verified_purchase  \
# 0              0            0    N                 Y
# 1              0            0    N                 Y
# 2              1            1    N                 Y
# 3              0            0    N                 Y
# 4              4            5    N                 Y
#
#                      review_headline  \
# 0          It really is INCREDIBLE!!
# 1                    Changed my life
# 2                    Prodental spray
# 3                     Perfect Device
# 4  You are awesome and he's an idiot
#
#                                          review_body  review_date  year  \
# 0  This is the best stuff ever!! It cleans pet st...        15953  2013
# 1  I will never buy another soap again.  I use th...        15894  2013
# 2  works great, helps alot with smelly dog breath...        16141  2014
# 3            The perfect device for a new technology        16340  2014
# 4  You're looking up books like this and reading ...        15534  2012
#
#   product_category
# 0             Home
# 1           Beauty
# 2     Pet_Products
# 3         Wireless
# 4            Books

# %%
variables = df[['product_title','star_rating','helpful_votes',
                'total_votes', 'vine', 'verified_purchase',
                'review_headline', 'review_body', 'review_date', 'year', 'product_category']]

# %%
variables['review_wordcnt'] = variables['review_body'].map(lambda x : len(str(x).split()))
# Out:
# C:\Users\isaac\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
ppCols = variables[['star_rating', 'total_votes', 'review_wordcnt']]

sns.pairplot(ppCols)

# %%
variables['review_wordcnt'].hist(bins = 5)

# %% [markdown]
# It seems that there a number of outliers that are skewing our data quit a bit lets set a limit on the word count and the number of votes for a review to get a better picture of the data

# %%
removed_outliers = variables[variables['review_wordcnt']<900]
removed_outliers = variables[variables['total_votes']<900]

# %%
print("without outliers: ", len(removed_outliers))
print("with outliers: ", len(df))
# Out:
# without outliers:  49996
# with outliers:  49999

# %% [markdown]
# removeing the outliers we only drop 3 entries

# %%
ppCols = removed_outliers[['star_rating', 'total_votes', 'review_wordcnt']]
sns.pairplot(ppCols)

# %%
removed_outliers['review_wordcnt'].hist(bins = 5)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
corpus = df['review_body']

vectorizer = TfidfVectorizer(sublinear_tf=True, min_df=15, 
    stop_words='english', ngram_range=(1,2))

features = vectorizer.fit_transform(corpus).toarray()
